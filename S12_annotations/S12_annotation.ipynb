# %%
from anno import Annotator
import pandas as pd
import numpy as np
import json

# %%
annotate = Annotator('annotation_2.json', 'results.csv')

# %%
annotate.show_bboxes()

# %%
annotate.create_cluster(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   f"KMeans is known to have a memory leak on Windows "

# %%
annotate.show_k(6)
# Out:
# Centroids: [[0.08981924 0.08509939]
#  [0.34007824 0.35725497]
#  [0.1671334  0.25759702]
#  [0.20609951 0.11497557]
#  [0.23517202 0.50142955]
#  [0.61976323 0.38107832]
#  [0.35732505 0.16622659]]
# Mean IOU: 0.6340288866297397

# %%
###6 Cluster Solution
